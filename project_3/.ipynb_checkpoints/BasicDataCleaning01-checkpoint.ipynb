# %% [markdown]
# # Basic Data Cleaning

# %% [markdown]
# ## Importing libraries

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing a dataset 
video1=pd.read_csv('comments_3ec7JE-Dk8c.csv')
# Out:
# /var/folders/g3/96mgjdps6rdd3p34rf7fbqbr0000gn/T/ipykernel_4029/1170964962.py:2: DtypeWarning: Columns (7,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   video1=pd.read_csv('comments_3ec7JE-Dk8c.csv')

# %%
#Inspecting overview of data
print(video1.shape)
video1.head()
# Out:
# (115113, 14)
#        videoId                                        textDisplay  \
# 0  3ec7JE-Dk8c  why war again to creat around China ? Taiwan j...
# 1  3ec7JE-Dk8c  do filipinos realizes this, when china visits ...
# 2  3ec7JE-Dk8c  china will be the worlds biggest economy, chin...
# 3  3ec7JE-Dk8c  filipines should be smart and request the US t...
# 4  3ec7JE-Dk8c  World knows how much marine life destroyed by ...
#
#                                         textOriginal authorDisplayName  \
# 0  why war again to creat around China ? Taiwan j...        F. CS 中 Wu
# 1  do filipinos realizes this, when china visits ...            kimeli
# 2  china will be the worlds biggest economy, chin...            Know L
# 3  filipines should be smart and request the US t...     blacksheepdog
# 4  World knows how much marine life destroyed by ...   Jimboi Caminade
#
#                                authorProfileImageUrl  \
# 0  https://yt3.ggpht.com/ytc/AGIKgqNqg_iJQQ6YvbaW...
# 1  https://yt3.ggpht.com/ytc/AGIKgqNCKE7V6M-SHYHI...
# 2  https://yt3.ggpht.com/ytc/AGIKgqNQNddMe0uaYgad...
# 3  https://yt3.ggpht.com/ytc/AGIKgqMBis7nb_jYJ2BU...
# 4  https://yt3.ggpht.com/opv8kbyiWs2SgRKjqJPh40M-...
#
#                                     authorChannelUrl  \
# 0  http://www.youtube.com/channel/UCr78nle8I7-_p5...
# 1  http://www.youtube.com/channel/UCl-5_yAY0eQ8Jw...
# 2  http://www.youtube.com/channel/UCMuSbgvXBlLS6z...
# 3  http://www.youtube.com/channel/UCrmFgEL3FrVlVs...
# 4  http://www.youtube.com/channel/UC51PVzbcLDLqZu...
#
#                          authorChannelId canRate viewerRating likeCount  \
# 0  {'value': 'UCr78nle8I7-_p5S9zkEbJgQ'}    True         none         0
# 1  {'value': 'UCl-5_yAY0eQ8Jw9UJFUiamQ'}    True         none         0
# 2  {'value': 'UCMuSbgvXBlLS6zOzZF85hEQ'}    True         none         1
# 3  {'value': 'UCrmFgEL3FrVlVscN0_xbcDA'}    True         none         0
# 4  {'value': 'UC51PVzbcLDLqZuJNHKXJ9WQ'}    True         none         0
#
#             publishedAt             updatedAt parent_id  \
# 0  2023-04-22T19:24:44Z  2023-04-22T19:24:44Z       NaN
# 1  2023-04-22T08:15:21Z  2023-04-22T08:15:21Z       NaN
# 2  2023-04-21T17:57:09Z  2023-04-21T17:57:09Z       NaN
# 3  2023-04-21T06:32:39Z  2023-04-21T06:32:39Z       NaN
# 4  2023-04-21T05:41:51Z  2023-04-21T05:41:51Z       NaN
#
#                    comment_id
# 0  Ugzt00yWE6m-W9PB7cJ4AaABAg
# 1  UgyIv3rtFQYOkwGhRHp4AaABAg
# 2  UgyDzHxmKL67pE2Z5FR4AaABAg
# 3  Ugynwn1_GwCehvCAXKV4AaABAg
# 4  UgxgSFrz5fMvDD2jD_Z4AaABAg

# %% [markdown]
# ## Data Cleaning

# %%
#Checking for null values
video1.isnull().sum()
# Out:
# videoId                       0
# textDisplay                   0
# textOriginal                  0
# authorDisplayName           400
# authorProfileImageUrl         0
# authorChannelUrl              0
# authorChannelId               0
# canRate                       0
# viewerRating                  0
# likeCount                     0
# publishedAt                   0
# updatedAt                     0
# parent_id                114133
# comment_id                    0
# dtype: int64

# %% [markdown]
# In the extraction of data from Youtube's API, parent_id is set to None to keep the dataframe shape since there is no need to understand if a comment is a reply to another comment. Thus, this column is removed.

# %%
#Dropping parent_id column
video1.drop('parent_id',axis=1,inplace=True)

# %%
#Reseting the index
video1.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Column 01: videoId

# %% [markdown]
# Since these are the comments from the same video, all the entries for video ID will be the same. Thus it is unecessary to keep it.

# %%
#Dropping column
video1.drop('videoId', axis=1, inplace=True)

# %% [markdown]
# ### Column 02: textOriginal

# %%
#Filtering different values in these columns
diff_val=video1[video1['textDisplay']!=video1['textOriginal']][['textDisplay','textOriginal']]

# %%
#Quick overview of different values
diff_val.head()
# Out:
#                                           textDisplay  \
# 4   World knows how much marine life destroyed by ...
# 7   I participated in Balikatan 2016 so this is no...
# 8   @JBZA china is just paper tiger and everyone k...
# 9   @JBZA only in vnm. middle east cant compare to...
# 10  @JBZA Are you just retarded ? Di you forget al...
#
#                                          textOriginal
# 4   World knows how much marine life destroyed by ...
# 7   I participated in Balikatan 2016 so this is no...
# 8   @JBZA china is just paper tiger and everyone k...
# 9   @JBZA only in vnm. middle east cant compare to...
# 10  @JBZA Are you just retarded ? Di you forget al...

# %%
#Set of differnet values in the columns
char_set = set()
for row_index in range(len(diff_val)):
    string1=diff_val.iloc[row_index][0]
    string2=diff_val.iloc[row_index][1]
    for char in string1:
        if char not in string2:
            char_set.add(char)
    for char in string2:
        if char not in string1:
            char_set.add(char)
print(char_set)
# Out:
# {'J', '-', '\n', 'E', 'f', 'm', '=', '*', '9', '3', '>', 'D', 'z', 'b', 'u', 'd', ';', "'", '?', 'v', 'l', 'q', '#', 'S', '0', '<', 'a', '%', ' ', 'g', '"', '8', 'A', 'p', '/', '2', 'e', '7', '&', 'F', 'C', 'w', ':', 'r', 't', 'o'}

# %% [markdown]
# The column, 'textOriginal' will be dropped and column, 'textDisplay' will be kept instead as the content of the messages are intact except for some formatting. Additionally, since textDisplay is the filtered and formatted vesion that other viewers experience on Youtube, it is more relevant to use it for our classification problem.

# %%
#Dropping column
video1.drop(columns='textOriginal', inplace=True)

# %% [markdown]
# ### Column 03: textDisplay

# %% [markdown]
# As explained above, textDisplay will be kept for more relevant training of the classification model. Further processing of the text will take place in later sections.

# %% [markdown]
# ### Column 04: author-related

# %% [markdown]
# Information on commented viewer's related details such as their ID, profile picture URL, channel ID are not relevant thus these are dropped.

# %%
video1.columns
# Out:
# Index(['textDisplay', 'authorDisplayName', 'authorProfileImageUrl',
#        'authorChannelUrl', 'authorChannelId', 'canRate', 'viewerRating',
#        'likeCount', 'publishedAt', 'updatedAt', 'comment_id'],
#       dtype='object')

# %%
#Dropping author-related columns
video1.drop(columns=['authorDisplayName',
       'authorProfileImageUrl', 'authorChannelUrl', 'authorChannelId'], inplace=True)

# %%
video1.shape
# Out:
# (115113, 7)

# %% [markdown]
# ### Column 05: canRate

# %% [markdown]
# Column that captures the ability for an authenicated user to rate comments.

# %%
#Overview of values
video1['canRate'].describe()
# Out:
# count     115113
# unique       134
# top         True
# freq       65536
# Name: canRate, dtype: object

# %% [markdown]
# All values in the column is True and it does not add value to our classification model thus this is dropped.

# %%
#Dropping canRate column
video1.drop('canRate', axis=1, inplace=True)

# %% [markdown]
# ### Column 06: viewerRating

# %% [markdown]
# To capture the authenicated user(user that authenicate the API request) sentiment on the comment. Not relevant in our classification model training, thus it is dropped.

# %%
#Overview
video1['viewerRating'].describe()
# Out:
# count     115113
# unique         2
# top         none
# freq      114133
# Name: viewerRating, dtype: object

# %%
video1.drop('viewerRating', axis=1, inplace=True)

# %% [markdown]
# ### Column 07: likeCount (Consider if keep/remove, if remove then dont need to drop)

# %% [markdown]
# To caputure the amount of likes of the comment

# %%
#Overview
video1['likeCount'].describe()
# Out:
# count     115113
# unique        29
# top            0
# freq       45554
# Name: likeCount, dtype: int64

# %%
#Checking for anomaly entries
video1['likeCount'].unique()
# Out:
# array([0, 1, 2, 3, 10, 4, 5, 6, 14, 17, 16, 8, 11, 7, '0', '1', '2', '4',
#        '3', '5', '6', '14', '17', '16', '8', '11', '7', '10', 'none'],
#       dtype=object)

# %% [markdown]
# - There are 'none' entries which will be treated as null and dropped from the dataset.
# - Some numeric values are in string types, they will be type casted as int.

# %%
#Dropping "none" entries by its row
video1.drop(index=video1[video1['likeCount'] == 'none'].index, inplace=True)

# %%
#Typecasting to integers
video1['likeCount']=video1['likeCount'].astype(int)

# %% [markdown]
# ### Column 08: Time of comment

# %% [markdown]
# Captures the date and time of comment published and updated. Not relevant in training of classification model thus it is dropped.

# %%
#Dropping of column
video1.drop(['publishedAt', 'updatedAt'], axis=1, inplace=True)

# %% [markdown]
# ### Column 09: comment_id

# %% [markdown]
# Tagging of comment. Not relevant thus dropped.

# %%
#Dropping of column
video1.drop('comment_id', axis=1, inplace=True)

# %%
video1.isnull().sum()
# Out:
# textDisplay    0
# likeCount      0
# dtype: int64

# %% [markdown]
# ## Dropping duplicates

# %%
#Dropping duplicated columns
video1.drop_duplicates(inplace=True)

# %% [markdown]
# # Consolidating datasets

# %% [markdown]
# ## Function for basic cleaning and exporting dataset

# %% [markdown]
# Since the dataframe structure of comments drawn from Youtube's API is similar, a function is created to simplify the process of the basic cleaning.

# %%
#Creating basic cleaning function

def basic_clean_toCsv(data):
    
    data.reset_index(drop=True, inplace=True)
    
    data.drop(['videoId', 'authorDisplayName',
       'authorProfileImageUrl', 'authorChannelUrl', 'authorChannelId',
       'canRate', 'viewerRating', 'publishedAt', 'updatedAt',
       'parent_id', 'comment_id', 'textOriginal'], axis=1, inplace=True)
    
    #Dropping "none" entries by its row in column, 'likeCount' 
    data.drop(index=data[data['likeCount'] == 'none'].index, inplace=True)      #Delete if not keeping the column
    #Typecasting to integers
    data['likeCount']=data['likeCount'].astype(int)
    
    data.drop_duplicates(inplace=True)
    
    if not all(col in data.columns for col in ['textDisplay', 'likeCount']): #Change this accordingly to the final columns we want to preserve
        raise ValueError("Dataframe not in desired format")
         
    else:
        return data

# %% [markdown]
# To apply the basic cleaning steps as shown above across all extracted comments csv.

# %%
#importing all csv files

#Getting the video id tags
# %store -r video_ids

for i, ID in enumerate(video_ids):
    df_name=f'df_{i+1}'
    globals()[df_name]=pd.read_csv(f'comments_{ID}.csv')

# %% [markdown]
# Due to some corruption of the dataset when drawing from Youtube's API, there is a misalignment of the column, likeCount. Some corrections are carried out to rectify this before proceeding with the basic cleaning process.

# %%
#Aligning the like column in problematic datasets
def realign_col(data):
    actual_likeCount=data[data['viewerRating']!='none']['viewerRating']
    data.loc[data['viewerRating']!='none','likeCount']=actual_likeCount

# %%
#Applying the realignment across problematic dataframes
for i in [2,3,6,7]:
    realign_col(eval(f"df_{i}"))
    eval(f"df_{i}").rename(columns={'parentId':'parent_id'},inplace=True)

#df_5 is corrupted uniquely so it is dealth with individually
actual_likeCount_5=df_5[df_5['publishedAt'].astype(str).str.len() < 3]['publishedAt']
df_5.loc[df_5['likeCount']=='none','likeCount']=actual_likeCount_5

# %%
#Basic cleaning of all datasets

#Creating a list of dataframes
df_list=[]
for i in range(1, len(video_ids)+1):
    df_list.append(eval(f"df_{i}"))

for i in df_list:    
    i=basic_clean_toCsv(i) #Can remove 'i=' if we are removing the likeCount column

# %% [markdown]
# ## Concatenating the datasets

# %%
#Concatenating all the comments datasets
final_df=pd.concat(df_list)

#Reseting the index
final_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Exporting the final dataset

# %%
#Quick overview of final_df 
print(final_df.shape)
final_df.head()
# Out:
# (1290, 2)
#                                          textDisplay  likeCount
# 0  why war again to creat around China ? Taiwan j...          0
# 1  do filipinos realizes this, when china visits ...          0
# 2  china will be the worlds biggest economy, chin...          1
# 3  filipines should be smart and request the US t...          0
# 4  World knows how much marine life destroyed by ...          0

# %%
#Check on null values again before exporting to csv
final_df.isnull().sum()

# %%
#Exporting to csv
final_df.to_csv('final_df.csv', index=False)

# %% [markdown]
# # Establishing Y labels

# %% [markdown]
# ##  to create y labels

# %%
from googleapiclient import discovery
import json

API_KEY = 'AIzaSyB4RDwXJsoxS_PwdyZ-Q_NjzctaXFSlIbQ'

client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  static_discovery=False,
)

total_list=[]
for i, row in enumerate(final_df['textDisplay']):
    try:
        analyze_request = {
          'comment': { 'text': row },
          'requestedAttributes': {'TOXICITY': {}, 'INSULT': {}, 'THREAT' : {}, 'IDENTITY_ATTACK': {}}
        }
        response = client.comments().analyze(body=analyze_request).execute()
        
        keys=[att for att in response['attributeScores']]
        keys.append('index')
        values=[response['attributeScores'][i]['summaryScore']['value'] for i in keys[:-1]]
        values.append(i)
        total_list.append(dict(zip(keys,values)))
        print(keys)
        time.sleep(2)
        
    except:
        continue
    

toxic_score_df=pd.DataFrame(total_list)
# Out:
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ...
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'INSULT', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'THREAT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['THREAT', 'INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'index']
# ['INSULT', 'IDENTITY_ATTACK', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'THREAT', 'INSULT', 'TOXICITY', 'index']
# ['IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'THREAT', 'index']
# ['TOXICITY', 'INSULT', 'THREAT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'THREAT', 'TOXICITY', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'index']
# ['INSULT', 'THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'index']
# ['THREAT', 'IDENTITY_ATTACK', 'TOXICITY', 'INSULT', 'index']
# ['THREAT', 'TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'index']
# ['INSULT', 'TOXICITY', 'IDENTITY_ATTACK', 'THREAT', 'index']
# ['TOXICITY', 'THREAT', 'INSULT', 'IDENTITY_ATTACK', 'index']
# ['IDENTITY_ATTACK', 'INSULT', 'TOXICITY', 'THREAT', 'index']

# %%
#Preparing comment scores for merging
toxic_score_df.rename(columns={'index':'number'},inplace=True)

#Merging of comment scores to initial dataframe
merged_df = final_df.merge(toxic_score_df, left_index=True, right_on='number',how='right')
merged_df.drop(columns='number', inplace=True)
merged_df.reset_index(drop=True, inplace=True)

# %%
merged_df
# Out:
#                                             textDisplay  likeCount    THREAT  \
# 0     why war again to creat around China ? Taiwan j...          0  0.011353
# 1     do filipinos realizes this, when china visits ...          0  0.009593
# 2     china will be the worlds biggest economy, chin...          1  0.011457
# 3     filipines should be smart and request the US t...          0  0.025271
# 4     World knows how much marine life destroyed by ...          0  0.138020
# ...                                                 ...        ...       ...
# 1077  They are so shameless, they are the origin of ...          5  0.009075
# 1078  @콩나물국에밥  &quot;Then you can be what you love, ...          0  0.009567
# 1079  @老不懂 I love dog more than Chinese 😁👍 Thanks a ...          0  0.012492
# 1080  coward like a dog against usa but like to bull...          0  0.074765
# 1081  fk excuses. you chinese like to bully koreans ...          0  0.020609
#
#       TOXICITY  IDENTITY_ATTACK    INSULT
# 0     0.070546         0.025203  0.018839
# 1     0.157667         0.159452  0.033240
# 2     0.112127         0.067497  0.023609
# 3     0.175451         0.120924  0.063549
# 4     0.602039         0.450876  0.474728
# ...        ...              ...       ...
# 1077  0.521400         0.102216  0.573987
# 1078  0.274129         0.009101  0.209019
# 1079  0.644471         0.571504  0.573987
# 1080  0.836470         0.513580  0.539327
# 1081  0.305399         0.261558  0.223032
#
# [1082 rows x 6 columns]

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Overview of features (besides text comments)

# %% [markdown]
# To have an understanding on some of the features with relation to the comments

# %% [markdown]
# ### Distribution of attributes

# %%
#Plotting distribution of the various attribute scores
fig,axs=plt.subplots(4,1, figsize=(10,20))


for i, col in enumerate(merged_df.columns[2:6]): 
    axs[i].hist(merged_df[col], bins=20)
    axs[i].set_xlabel(f'{col} score')
    axs[i].set_ylabel('Frequency')
    if i == 0:
        axs[i].set_title('Distribution of attributes', fontsize=20);

# %% [markdown]
# ### Distribution of likes

# %%
plt.hist(merged_df['likeCount'], bins =20);

# %% [markdown]
# #### Distribution between likes and attributes

# %%
#Relation between likes of a comment and toxicity score
fig_1,axs_1=plt.subplots (4,1, figsize=(10,20))

for i, col in enumerate(merged_df.columns[2:6]):
    axs_1[i].scatter(data=merged_df, x='likeCount', y=col, alpha=0.5, c=(merged_df[col] >= 0.6),cmap='coolwarm')
    axs_1[i].set_xlabel(f'Counts of liked comments')
    axs_1[i].set_ylabel(f'{col} score')
    if i == 0:
        axs_1[i].set_title('Liked comments VS Attributes', fontsize=20);

# %%
sns.pairplot(merged_df)
